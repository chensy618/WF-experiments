# %% [markdown]
# # Summary: 2016 vs 2022 Cross-Year RMSE Comparison
#
# Aggregates results from the two experiment notebooks (2016, 2022) into summary plots.
#
# **Prerequisites:** run the 2016 and 2022 experiment notebooks first so that `metrics.csv` is saved in each figure directory.
#
# | Year | Period | Models |
# |---|---|---|
# | 2016 | 2016-01-01 → 2016-04-08 | FCN3, HRES |
# | 2022 | 2022-01-01 → 2022-04-08 | FCN3, GraphCast, Pangu, HRES |
#
# All comparisons: +12 h lead, valid 12:00 UTC, obs = 12h trailing mean.

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from pathlib import Path

# %%
FIG_BASE = Path('/cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures')
FIG_OUT  = FIG_BASE / 'comparison_summary'
FIG_OUT.mkdir(parents=True, exist_ok=True)

METRIC_PATHS = {
    '2016': FIG_BASE / 'fcn3_hres_2016'              / 'metrics.csv',
    '2022': FIG_BASE / 'fcn3_gc_pangu_hres_2022_12h' / 'metrics.csv',
}

STATIONS = {
    'SN88690': 'Hekkingen Fyr',
    'SN90490': 'Tromsoe-Langnes',
    'SN90760': 'Fakken',
}

CLR = {
    'FCN3':      '#E74C3C',
    'GraphCast': '#2980B9',
    'Pangu':     '#16A085',
    'HRES':      '#E67E22',
}

AI_MODELS      = ['FCN3', 'GraphCast', 'Pangu']
PHYSICS_MODELS = ['HRES']

# %% [markdown]
# ## 1  Load Metrics from Experiment Notebooks

# %%
dfs = {}
for year, path in METRIC_PATHS.items():
    if not path.exists():
        print(f'WARNING: {path} not found. Run the {year} notebook first.')
        continue
    df = pd.read_csv(path, index_col=0)
    dfs[year] = df
    print(f'{year}: {df.shape[0]} rows, models={[c.split()[0] for c in df.columns if "RMSE" in c]}')

if not dfs:
    raise RuntimeError('No metrics CSVs found. Run both experiment notebooks first.')
# Out:
# 2016: 4 rows, models=['FCN3', 'HRES', 'ΔRMSE']
# 2022: 4 rows, models=['FCN3', 'GraphCast', 'HRES', 'Pangu', 'ΔRMSE', 'ΔRMSE', 'ΔRMSE']

# %% [markdown]
# ## 2  AI-based vs Physics-based Model Performance

# %%
sids_all = list(STATIONS.keys()) + ['All Stations']
years    = [y for y in ['2016', '2022'] if y in dfs]

fig, axes = plt.subplots(1, len(sids_all), figsize=(5.5 * len(sids_all), 5.5), squeeze=False)
axes = axes[0]

all_models_ordered = ['FCN3', 'GraphCast', 'Pangu', 'HRES']

for col, sid in enumerate(sids_all):
    ax = axes[col]
    x_ticks, x_labels = [], []

    for i, model in enumerate(all_models_ordered):
        rmse_col = f'{model} RMSE'
        vals_by_year = {}
        for yr in years:
            if yr not in dfs: continue
            df = dfs[yr]
            if rmse_col not in df.columns: continue
            if sid not in df.index: continue
            vals_by_year[yr] = float(df.loc[sid, rmse_col])

        if not vals_by_year:
            continue

        n_yrs = len(vals_by_year)
        offsets = np.linspace(-0.25, 0.25, n_yrs)
        for j, (yr, rmse) in enumerate(sorted(vals_by_year.items())):
            clr = CLR.get(model, 'gray')
            alpha = 0.55 + 0.15 * j
            ax.bar(i + offsets[j], rmse, 0.22, color=clr, alpha=alpha,
                   label=f'{model} {yr}' if col == 0 else '_')
            ax.text(i + offsets[j], rmse + 0.05, f'{rmse:.2f}',
                    ha='center', va='bottom', fontsize=6.5, rotation=45)

        x_ticks.append(i)
        x_labels.append(model)

    n_ai = sum(1 for m in all_models_ordered if m in AI_MODELS and
               any(f'{m} RMSE' in dfs[y].columns for y in years if y in dfs))
    if n_ai > 0:
        ax.axvspan(-0.5, n_ai - 0.5, color='#FADBD8', alpha=0.25, zorder=0)
        ax.axvspan(n_ai - 0.5, len(all_models_ordered) - 0.5,
                   color='#FDEBD0', alpha=0.25, zorder=0)

    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_labels, fontsize=10, rotation=15, ha='right')
    ax.set_ylabel('RMSE (m/s)', fontsize=11)
    label = STATIONS.get(sid, sid)
    ax.set_title(f'{sid}' + (f'\n{label}' if sid != 'All Stations' else ''), fontsize=11, fontweight='bold')
    ax.grid(axis='y', alpha=0.3)

from matplotlib.patches import Patch
handles = [Patch(facecolor='gray', alpha=0.55+0.15*j, label=yr)
           for j, yr in enumerate(sorted(years))]
handles += [Patch(facecolor='#FADBD8', alpha=0.6, label='AI-based region'),
            Patch(facecolor='#FDEBD0', alpha=0.6, label='Physics region')]
fig.legend(handles=handles, fontsize=9, loc='upper right', bbox_to_anchor=(1, 1))

fig.suptitle('AI-based vs Physics-based Model RMSE  |  10 m Wind Speed  |  +12 h Lead\n2016-01-01 → 2016-04-08  &  2022-01-01 → 2022-04-08',
             fontsize=13, fontweight='bold')
plt.tight_layout()
out = FIG_OUT / 'ai_vs_physics_rmse.png'
plt.savefig(out, dpi=130, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/ai_vs_physics_rmse.png

# %% [markdown]
# ## 3  RMSE Comparison Across Years (2016 / 2022)

# %%
years_num = {'2016': 2016, '2022': 2022}
sids_all  = list(STATIONS.keys()) + ['All Stations']

fig, axes = plt.subplots(1, len(sids_all), figsize=(5.5 * len(sids_all), 5), squeeze=False)
axes = axes[0]

for col, sid in enumerate(sids_all):
    ax = axes[col]

    for model in ['FCN3', 'GraphCast', 'Pangu', 'HRES']:
        rmse_col = f'{model} RMSE'
        pts = []
        for yr in sorted(years_num.keys()):
            if yr not in dfs: continue
            df = dfs[yr]
            if rmse_col not in df.columns: continue
            if sid not in df.index: continue
            pts.append((years_num[yr], float(df.loc[sid, rmse_col])))

        if not pts:
            continue

        xs = [p[0] for p in pts]
        ys = [p[1] for p in pts]
        clr = CLR.get(model, 'gray')

        if len(xs) == 1:
            ax.scatter(xs, ys, color=clr, s=80, zorder=5,
                       marker='*', label=f'{model} (2022 only)')
            ax.annotate(f'{ys[0]:.3f}', (xs[0], ys[0]),
                        textcoords='offset points', xytext=(6, 4), fontsize=8, color=clr)
        else:
            ls = '-' if model in AI_MODELS else '--'
            ax.plot(xs, ys, color=clr, lw=2.0, linestyle=ls, marker='o', ms=7, label=model)
            for x, y in zip(xs, ys):
                ax.annotate(f'{y:.3f}', (x, y),
                            textcoords='offset points', xytext=(5, 5), fontsize=8, color=clr)

    ax.set_xticks(sorted(years_num.values()))
    ax.set_xticklabels(sorted(years_num.keys()), fontsize=11)
    ax.set_xlabel('Year', fontsize=11)
    ax.set_ylabel('RMSE (m/s)', fontsize=11)
    label = STATIONS.get(sid, sid)
    ax.set_title(f'{sid}' + (f'\n{label}' if sid != 'All Stations' else ''), fontsize=11, fontweight='bold')
    ax.legend(fontsize=8, loc='upper right')
    ax.grid(alpha=0.3)
    ax.set_xlim(2014.5, 2023.5)

fig.suptitle('RMSE Comparison: 2016 vs 2022  |  10 m Wind Speed  |  +12 h Lead\n'
             'Solid lines = AI-based  |  Dashed = Physics (HRES)  |  Stars = 2022-only models',
             fontsize=12, fontweight='bold')
plt.tight_layout()
out = FIG_OUT / 'rmse_across_years.png'
plt.savefig(out, dpi=130, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/rmse_across_years.png

# %% [markdown]
# ## 4  Two-Year Integrated Bar Chart

# %%
years         = [y for y in ['2016', '2022'] if y in dfs]
models_2year  = ['FCN3', 'HRES']
sids_all      = list(STATIONS.keys()) + ['All Stations']
labels        = [f'{s}\n{STATIONS.get(s, s)}' for s in sids_all]

x        = np.arange(len(sids_all))
n_combos = len(models_2year) * len(years)
w        = 0.11
offsets  = np.linspace(-(n_combos - 1) / 2, (n_combos - 1) / 2, n_combos) * w

YEAR_ALPHA = {'2016': 1.00, '2022': 0.55}
YEAR_HATCH = {'2016': '',   '2022': 'xx'}

fig, axes = plt.subplots(1, 2, figsize=(18, 5))

for ax, (metric, ylabel, title) in zip(
    axes,
    [('RMSE', 'RMSE (m/s)', 'Root Mean Square Error  –  FCN3 vs HRES  (2016 / 2022)'),
     ('Bias', 'Bias (m/s)', 'Mean Bias  –  FCN3 vs HRES  (2016 / 2022)')],
):
    bar_handles = []
    idx = 0
    for model in models_2year:
        clr = CLR[model]
        for yr in years:
            df = dfs.get(yr)
            col = f'{model} {metric}'
            if df is None or col not in df.columns:
                idx += 1
                continue

            vals = [float(df.loc[sid, col]) if sid in df.index else np.nan
                    for sid in sids_all]
            bars = ax.bar(
                x + offsets[idx], vals, w,
                color=clr,
                alpha=YEAR_ALPHA[yr],
                hatch=YEAR_HATCH[yr],
                edgecolor='white' if not YEAR_HATCH[yr] else clr,
                label=f'{model} {yr}',
            )
            bar_handles.append(bars[0])

            for bar, v in zip(bars, vals):
                if not np.isnan(v):
                    h = bar.get_height()
                    sign = 1 if h >= 0 else -1
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        h + sign * 0.02,
                        f'{v:+.2f}' if metric == 'Bias' else f'{v:.2f}',
                        ha='center',
                        va='bottom' if h >= 0 else 'top',
                        fontsize=6,
                        rotation=90,
                    )
            idx += 1

    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=10)
    ax.set_ylabel(ylabel, fontsize=12)
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.legend(handles=bar_handles, fontsize=8, ncol=2, loc='upper right')
    ax.grid(axis='y', alpha=0.35)

    if metric == 'Bias':
        ax.axhline(0, color='k', lw=0.9, linestyle='--', alpha=0.6)
        all_vals = [float(dfs[yr].loc[sid, f'{m} Bias'])
                    for yr in years for m in models_2year for sid in sids_all
                    if yr in dfs and f'{m} Bias' in dfs[yr].columns and sid in dfs[yr].index]
        if all_vals:
            lim = max(abs(v) for v in all_vals) * 1.5
            ax.set_ylim(-lim, lim)
    else:
        all_vals = [float(dfs[yr].loc[sid, f'{m} RMSE'])
                    for yr in years for m in models_2year for sid in sids_all
                    if yr in dfs and f'{m} RMSE' in dfs[yr].columns and sid in dfs[yr].index]
        if all_vals:
            ax.set_ylim(0, max(all_vals) * 1.35)

fig.suptitle(
    'Two-Year Comparison: FCN3 vs HRES  |  10 m Wind Speed  |  +12 h Lead\n'
    'Solid = 2016  |  Cross-hatched (xx) = 2022',
    fontsize=13, fontweight='bold',
)
plt.tight_layout()
out = FIG_OUT / 'two_year_bar_chart.png'
plt.savefig(out, dpi=130, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/two_year_bar_chart.png

# %% [markdown]
# ## 5  Combined Metrics Table

# %%
rows = []
for yr, df in sorted(dfs.items()):
    rmse_cols = [c for c in df.columns if 'RMSE' in c]
    bias_cols = [c for c in df.columns if 'Bias' in c]
    for sid in list(STATIONS.keys()) + ['All Stations']:
        if sid not in df.index: continue
        row = {'Year': yr, 'Station': sid}
        for c in rmse_cols + bias_cols:
            row[c] = round(float(df.loc[sid, c]), 4)
        rows.append(row)

table = pd.DataFrame(rows)
print('Combined Metrics  |  +12 h Lead  |  2016-01-01 → 2016-04-08  &  2022-01-01 → 2022-04-08')
print('=' * 100)
print(table.to_string(index=False))
# Out:
# Combined Metrics  |  +12 h Lead  |  2016-01-01 → 2016-04-08  &  2022-01-01 → 2022-04-08
# ...
# Year      Station  FCN3 RMSE  HRES RMSE  ΔRMSE HRES−FCN3  FCN3 Bias  HRES Bias  GraphCast RMSE  Pangu RMSE  ΔRMSE GraphCast−FCN3  ΔRMSE Pangu−FCN3  GraphCast Bias  Pangu Bias
# 2016      SN88690     3.7940     4.8057           1.0118    -3.4337    -4.5149             NaN         NaN                   NaN               NaN             NaN         NaN
# 2016      SN90490     3.0855     3.5059           0.4205    -1.9008    -2.4112             NaN         NaN                   NaN               NaN             NaN         NaN
# 2016      SN90760     6.3114     5.4143          -0.8971    -5.6651    -4.3197             NaN         NaN                   NaN               NaN             NaN         NaN
# 2016 All Stations     4.5431     4.6166           0.0735    -3.6010    -3.7299             NaN         NaN                   NaN               NaN             NaN         NaN
# ...

# %% [markdown]
# ## 6  RMSE & Bias Bar Charts – 2016 vs 2022

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.transforms import blended_transform_factory

# ── Build DATA dynamically from loaded CSVs ──────────────────────────────────
DATA = {}
for yr, df in dfs.items():
    DATA[yr] = {}
    for sid in list(STATIONS.keys()) + ['All Stations']:
        if sid not in df.index:
            continue
        DATA[yr][sid] = {}
        for model in ['FCN3', 'GraphCast', 'Pangu', 'HRES']:
            rmse_col = f'{model} RMSE'
            bias_col = f'{model} Bias'
            if rmse_col in df.columns and bias_col in df.columns:
                DATA[yr][sid][model] = (
                    float(df.loc[sid, rmse_col]),
                    float(df.loc[sid, bias_col]),
                )

print('DATA loaded:')
for yr in DATA:
    for sid in DATA[yr]:
        models_avail = list(DATA[yr][sid].keys())
        print(f'  {yr} / {sid}: {models_avail}')
        break
# Out:
# DATA loaded:
#   2016 / SN88690: ['FCN3', 'HRES']
#   2022 / SN88690: ['FCN3', 'GraphCast', 'Pangu', 'HRES']

# %%
SIDS      = ['SN88690', 'SN90490', 'SN90760', 'All Stations']
SID_NAMES = {'SN88690': 'Hekkingen Fyr', 'SN90490': 'Tromsø-Langnes',
             'SN90760': 'Fakken',         'All Stations': ''}
YEARS    = [y for y in ['2016', '2022'] if y in DATA]

YEAR_MODELS = {
    '2016': [m for m in ['FCN3', 'HRES'] if any(m in DATA[y].get(sid, {}) for y in YEARS for sid in SIDS)],
    '2022': [m for m in ['FCN3', 'GraphCast', 'Pangu', 'HRES'] if any(m in DATA[y].get(sid, {}) for y in ['2022'] for sid in SIDS)],
}

# ── Layout parameters ─────────────────────────────────────────────────────────
w            = 0.20
yr_gap_far   = 0.40
sid_gap      = 0.70

YR_GAPS = {('2016', '2022'): yr_gap_far}

yr_tick_x = {}
sid_span  = {}

pos = 0.0
for sid in SIDS:
    first_left = pos
    for i_yr, yr in enumerate(YEARS):
        n        = len(YEAR_MODELS[yr])
        center   = pos + (n - 1) / 2.0 * w
        yr_tick_x[(sid, yr)] = center
        pos += n * w
        if i_yr < len(YEARS) - 1:
            pos += YR_GAPS[(yr, YEARS[i_yr + 1])]
    sid_span[sid] = (first_left, pos)
    pos += sid_gap


def bar_xpos(sid, yr, model):
    mlist = YEAR_MODELS[yr]
    if model not in mlist:
        return None
    j    = mlist.index(model)
    left = yr_tick_x[(sid, yr)] - (len(mlist) - 1) / 2.0 * w
    return left + j * w

# %% [markdown]
# ### RMSE

# %%
fig, ax = plt.subplots(figsize=(22, 6))

all_vals = []
for sid in SIDS:
    for yr in YEARS:
        for model in YEAR_MODELS[yr]:
            if model not in DATA[yr].get(sid, {}):
                continue
            val = DATA[yr][sid][model][0]
            all_vals.append(val)
            xp  = bar_xpos(sid, yr, model)
            ax.bar(xp, val, w * 0.88, color=CLR[model], alpha=0.85, zorder=3)
            ax.text(xp, val + 0.12, f'{val:.2f}',
                    ha='center', va='bottom', fontsize=16, rotation=90)

ax.set_xticks([yr_tick_x[(sid, yr)] for sid in SIDS for yr in YEARS])
ax.set_xticklabels([yr for _ in SIDS for yr in YEARS], fontsize=14)

trans = blended_transform_factory(ax.transData, ax.transAxes)
for sid in SIDS:
    xmid = (sid_span[sid][0] + sid_span[sid][1]) / 2
    name = SID_NAMES[sid]
    label = f'{sid}' + (f'\n{name}' if name else '')
    ax.text(xmid, -0.06, label, transform=trans, ha='center', va='top',
            fontsize=16, fontweight='bold', clip_on=False)

for sid in SIDS[:-1]:
    nxt = SIDS[SIDS.index(sid) + 1]
    sep = (sid_span[sid][1] + sid_span[nxt][0]) / 2
    ax.axvline(sep, color='gray', lw=0.9, linestyle='--', alpha=0.55, zorder=1)

ax.set_xlim(sid_span[SIDS[0]][0] - w, sid_span[SIDS[-1]][1] + w)
ax.set_ylim(0, max(all_vals) * 1.38)
ax.set_ylabel('RMSE (m/s)', fontsize=18)
ax.grid(axis='y', alpha=0.35, zorder=0)
ax.tick_params(axis='y', labelsize=14)

models_all = ['FCN3', 'GraphCast', 'Pangu', 'HRES']
handles = [mpatches.Patch(facecolor=CLR[m], alpha=0.85, label=m) for m in models_all]
ax.legend(handles=handles, fontsize=14, loc='upper left',
          title='Model', title_fontsize=13)

plt.tight_layout()
plt.subplots_adjust(bottom=0.10)
out = FIG_OUT / 'bar_rmse_2yr.png'
plt.savefig(out, dpi=300, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/bar_rmse_2yr.png

# %% [markdown]
# ### Bias

# %%
fig, ax = plt.subplots(figsize=(22, 6))

all_abs = []
for sid in SIDS:
    for yr in YEARS:
        for model in YEAR_MODELS[yr]:
            if model not in DATA[yr].get(sid, {}):
                continue
            val = DATA[yr][sid][model][1]
            all_abs.append(abs(val))
            xp  = bar_xpos(sid, yr, model)
            ax.bar(xp, val, w * 0.88, color=CLR[model], alpha=0.85, zorder=3)
            ax.text(xp, val - 0.15, f'{val:+.2f}',
                    ha='center', va='top', fontsize=16, rotation=90)

ax.axhline(0, color='k', lw=1.0, linestyle='--', alpha=0.55, zorder=2)

ax.set_xticks([yr_tick_x[(sid, yr)] for sid in SIDS for yr in YEARS])
ax.set_xticklabels([yr for _ in SIDS for yr in YEARS], fontsize=14)

trans = blended_transform_factory(ax.transData, ax.transAxes)
for sid in SIDS:
    xmid = (sid_span[sid][0] + sid_span[sid][1]) / 2
    name = SID_NAMES[sid]
    label = f'{sid}' + (f'\n{name}' if name else '')
    ax.text(xmid, -0.06, label, transform=trans, ha='center', va='top',
            fontsize=16, fontweight='bold', clip_on=False)

for sid in SIDS[:-1]:
    nxt = SIDS[SIDS.index(sid) + 1]
    sep = (sid_span[sid][1] + sid_span[nxt][0]) / 2
    ax.axvline(sep, color='gray', lw=0.9, linestyle='--', alpha=0.55, zorder=1)

ax.set_xlim(sid_span[SIDS[0]][0] - w, sid_span[SIDS[-1]][1] + w)
lim = max(all_abs) * 1.42 if all_abs else 8
ax.set_ylim(-lim, lim * 0.18)
ax.set_ylabel('Bias (m/s)', fontsize=18)
ax.grid(axis='y', alpha=0.35, zorder=0)
ax.tick_params(axis='y', labelsize=14)

models_all = ['FCN3', 'GraphCast', 'Pangu', 'HRES']
handles = [mpatches.Patch(facecolor=CLR[m], alpha=0.85, label=m) for m in models_all]
ax.legend(handles=handles, fontsize=14, loc='lower left',
          title='Model', title_fontsize=13)

# ax.set_title(
#     'Bias Comparison for 10 m Wind Speed Forecasts (+12 h Lead)\n'
#     '2016 (Jan–Apr): FCN3 vs HRES;  2022 (Jan–Apr): FCN3, GraphCast, Pangu, HRES',
#     fontsize=16, fontweight='bold',
# )
plt.tight_layout()
plt.subplots_adjust(bottom=0.10)
out = FIG_OUT / 'bar_bias_2yr.png'
plt.savefig(out, dpi=300, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/bar_bias_2yr.png

# %% [markdown]
# ## 7  Two-Year Time Series

# %%
import warnings; warnings.filterwarnings('ignore')
import nest_asyncio; nest_asyncio.apply()
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pathlib import Path
import json as _json

OBS_DIR    = Path('/cluster/home/siyan/github/WF-experiments/experiments/outputs/wind_obs')
HRES_PATH  = Path('/cluster/work/projects/nn8106k/siyan/weatherbench2_forecasts/hres/0p25/2016-2022-0012-1440x721.zarr')
PANGU_PATH = Path('/cluster/work/projects/nn8106k/siyan/weatherbench2_forecasts/pangu/0p25/2018-2022_0012_0p25.zarr')

TS_STATIONS = {
    'SN88690': {'name': 'Hekkingen Fyr',  'lat': 69.6005,  'lon': 17.8317},
    'SN90490': {'name': 'Tromsø-Langnes', 'lat': 69.6767,  'lon': 18.9133},
    'SN90760': {'name': 'Fakken',          'lat': 70.10426, 'lon': 20.11451},
}
OBS_NAMES = {
    'SN88690': 'SN88690_Hekkingen_Fyr',
    'SN90490': 'SN90490_Tromsoe_Langnes',
    'SN90760': 'SN90760_Fakken',
}

YEAR_CFG = {
    '2016': {
        'fcn3_dir': Path('/cluster/work/projects/nn8106k/siyan/WF-experiments/outputs/fcn3_station_weekly_multistep_2016'),
        'start': '2016-01-01',
        'end':   '2016-01-28',
    },
    '2022': {
        'fcn3_dir': Path('/cluster/work/projects/nn8106k/siyan/WF-experiments/outputs/fcn3_station_weekly_multistep_2022'),
        'gc_dir':   Path('/cluster/work/projects/nn8106k/siyan/WF-experiments/outputs/graphcast_operational_station_weekly_multistep_2022'),
        'start': '2022-01-01',
        'end':   '2022-01-28',
    },
}

LEAD_H = 12
CLR_TS = {'Obs': '#27AE60', 'FCN3': '#E74C3C', 'GraphCast': '#2980B9', 'Pangu': '#16A085', 'HRES': '#E67E22'}


def _nearest_idx(arr, t):
    return int(np.argmin(np.abs(arr - t)))


def _is_empty_zarr(path):
    try:
        m = _json.load(open(path / 'zarr.json'))
        return len(m.get('consolidated_metadata', {}).get('metadata', {})) == 0
    except Exception:
        return True


def load_obs(start, end):
    dfs = []
    for sid, base in OBS_NAMES.items():
        parts = []
        for yr in range(pd.Timestamp(start).year, pd.Timestamp(end).year + 1):
            f = OBS_DIR / f'{base}_{yr}.csv'
            if not f.exists(): continue
            df = pd.read_csv(f)
            df['valid_time'] = pd.to_datetime(df['time'], utc=True).dt.tz_localize(None)
            df['station'] = sid
            parts.append(df.rename(columns={'wind_speed': 'obs_wind'})[['station', 'valid_time', 'obs_wind']].dropna())
        if not parts: continue
        sdf = pd.concat(parts).sort_values('valid_time')
        sdf['obs_wind'] = sdf.set_index('valid_time')['obs_wind'].rolling('12h', min_periods=6).mean().values
        dfs.append(sdf.dropna(subset=['obs_wind']))
    obs = pd.concat(dfs, ignore_index=True)
    return obs[(obs['valid_time'] >= start) & (obs['valid_time'] <= end)]


def load_fcn3(fcn3_dir, lead_h):
    parts = []
    for f in sorted(fcn3_dir.glob('fcn3_station_wind_multistep_*.zarr')):
        if _is_empty_zarr(f): continue
        ds = xr.open_zarr(str(f), consolidated=True)
        lats, lons = ds['lat'].values, ds['lon'].values
        lt_raw = ds['lead_time'].values
        lt_h = (lt_raw / np.timedelta64(1, 'h')).astype(float) if np.issubdtype(lt_raw.dtype, np.timedelta64) else lt_raw.astype(float)
        lt_idx  = int(np.argmin(np.abs(lt_h - lead_h)))
        lt_used = float(lt_h[lt_idx])
        ws = np.sqrt(ds['u10m'].values**2 + ds['v10m'].values**2)
        for sid, info in TS_STATIONS.items():
            li = _nearest_idx(lats, info['lat'])
            oi = _nearest_idx(lons, info['lon'])
            for t_i, init_t in enumerate(pd.DatetimeIndex(ds['time'].values)):
                v = float(ws[t_i, lt_idx, li, oi])
                if not np.isnan(v):
                    parts.append({'station': sid, 'valid_time': init_t + pd.Timedelta(hours=lt_used), 'fcn3_wind': v})
    return pd.DataFrame(parts).drop_duplicates(['station', 'valid_time']).sort_values(['station', 'valid_time']).reset_index(drop=True)


def load_gc(gc_dir, lead_h):
    parts = []
    for f in sorted(gc_dir.glob('graphcast_station_wind_multistep_*.zarr')):
        ds = xr.open_zarr(str(f), consolidated=True)
        sids_list = [str(s) for s in ds['station'].values]
        tgt = np.timedelta64(int(lead_h * 3600), 's')
        lt_idx  = int(np.argmin(np.abs(ds['lead_time'].values - tgt)))
        lt_used = float(ds['lead_time'].values[lt_idx] / np.timedelta64(1, 's')) / 3600.0
        ws = ds['wind_speed_10m'].values
        for s_i, sid in enumerate(sids_list):
            for t_i, init_t in enumerate(pd.DatetimeIndex(ds['time'].values)):
                v = float(ws[s_i, t_i, lt_idx])
                if not np.isnan(v):
                    parts.append({'station': sid, 'valid_time': init_t + pd.Timedelta(hours=lt_used), 'gc_wind': v})
    df = pd.DataFrame(parts).drop_duplicates(['station', 'valid_time']).sort_values(['station', 'valid_time']).reset_index(drop=True)
    return df[df['valid_time'].dt.hour == 12].reset_index(drop=True)


def load_wb2(zarr_path, wind_var, lat_c, lon_c, lead_c, lead_h, start, end, col):
    ds = xr.open_zarr(str(zarr_path), consolidated=False)
    da = ds[wind_var].sel({lead_c: lead_h}).sel(time=slice(start, end))
    records = []
    for sid, info in TS_STATIONS.items():
        vals = da.sel({lat_c: info['lat'], lon_c: info['lon'] % 360}, method='nearest').values
        for t_i, init_t in enumerate(pd.DatetimeIndex(da['time'].values)):
            v = float(vals[t_i])
            if not np.isnan(v):
                records.append({'station': sid, 'valid_time': init_t + pd.Timedelta(hours=float(lead_h)), col: v})
    return pd.DataFrame(records).drop_duplicates(['station', 'valid_time']).sort_values(['station', 'valid_time']).reset_index(drop=True)

# %%
MERGED_TS = {}
for yr, cfg in YEAR_CFG.items():
    print(f'Loading {yr}...', end=' ', flush=True)
    start, end = cfg['start'], cfg['end']

    obs_df  = load_obs(start, end)
    fcn3_df = load_fcn3(cfg['fcn3_dir'], LEAD_H)
    hres_df = load_wb2(HRES_PATH, '10m_wind_speed', 'latitude', 'longitude',
                       'prediction_timedelta', LEAD_H, start, end, 'hres_wind')

    # Filter to period
    fcn3_df = fcn3_df[(fcn3_df['valid_time'] >= start) & (fcn3_df['valid_time'] <= end)]

    for _df in [fcn3_df, hres_df, obs_df]:
        _df['valid_time'] = _df['valid_time'].astype('datetime64[us]')

    m = pd.merge(fcn3_df[['station', 'valid_time', 'fcn3_wind']],
                 hres_df[['station', 'valid_time', 'hres_wind']],
                 on=['station', 'valid_time'], how='inner')

    if yr == '2022' and 'gc_dir' in cfg:
        gc_df    = load_gc(cfg['gc_dir'], LEAD_H)
        pangu_df = load_wb2(PANGU_PATH, '10m_wind_speed', 'latitude', 'longitude',
                            'prediction_timedelta', LEAD_H, start, end, 'pangu_wind')
        gc_df    = gc_df[(gc_df['valid_time'] >= start) & (gc_df['valid_time'] <= end)]
        gc_df['valid_time']    = gc_df['valid_time'].astype('datetime64[us]')
        pangu_df['valid_time'] = pangu_df['valid_time'].astype('datetime64[us]')
        m = pd.merge(m, gc_df[['station',    'valid_time', 'gc_wind']],    on=['station', 'valid_time'], how='inner')
        m = pd.merge(m, pangu_df[['station', 'valid_time', 'pangu_wind']], on=['station', 'valid_time'], how='inner')

    m = pd.merge(m, obs_df[['station', 'valid_time', 'obs_wind']],
                 on=['station', 'valid_time'], how='inner').dropna()
    MERGED_TS[yr] = m
    print(f'{len(m)} rows')
# Out:
# Loading 2016... 61 rows
# Loading 2022... 80 rows

# %%
YEARS_TS = [y for y in ['2016', '2022'] if y in MERGED_TS]
SIDS_TS  = list(TS_STATIONS.keys())

fig, axes = plt.subplots(len(YEARS_TS), 3, figsize=(20, 6 * len(YEARS_TS)), squeeze=False)

for row, yr in enumerate(YEARS_TS):
    cfg    = YEAR_CFG[yr]
    merged = MERGED_TS[yr]
    is_2022 = (yr == '2022')

    for col, sid in enumerate(SIDS_TS):
        ax  = axes[row, col]
        sub = merged[merged['station'] == sid].sort_values('valid_time')
        info = TS_STATIONS[sid]

        ax.plot(sub['valid_time'], sub['obs_wind'],
                color=CLR_TS['Obs'],  lw=2.0, label='Obs',  alpha=0.95, zorder=5)
        ax.plot(sub['valid_time'], sub['fcn3_wind'],
                color=CLR_TS['FCN3'], lw=1.3, label='FCN3', alpha=0.85, zorder=3)
        ax.plot(sub['valid_time'], sub['hres_wind'],
                color=CLR_TS['HRES'], lw=1.3, label='HRES', alpha=0.85, zorder=3, linestyle='--')

        if is_2022 and 'gc_wind' in sub.columns:
            ax.plot(sub['valid_time'], sub['gc_wind'],
                    color=CLR_TS['GraphCast'], lw=1.3, label='GC', alpha=0.80, zorder=2, linestyle=':')
        if is_2022 and 'pangu_wind' in sub.columns:
            ax.plot(sub['valid_time'], sub['pangu_wind'],
                    color=CLR_TS['Pangu'], lw=1.3, label='Pangu', alpha=0.80, zorder=2, linestyle='-.')

        if col == 0:
            ax.text(
                -0.20, 0.5, yr,
                transform=ax.transAxes,
                fontsize=24, fontweight='bold',
                rotation=90, va='center', ha='center',
            )

        if row == 0:
            ax.set_title(f'{sid} – {info["name"]}', fontsize=13, fontweight='bold')

        ax.set_ylabel('Wind Speed (m/s)', fontsize=12)
        ax.legend(loc='upper right', fontsize=10, ncol=5 if is_2022 else 3)
        ax.grid(True, alpha=0.3)
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=30, ha='right', fontsize=11)
        ax.tick_params(axis='y', labelsize=11)

axes[-1, 1].set_xlabel('Date (UTC)', fontsize=13)

# fig.suptitle(
#     'Time Series: 10 m Wind Speed – Jan 1 → Jan 28  |  +12 h Lead  |  2016 vs 2022',
#     fontsize=14, fontweight='bold', y=1.01,
# )
plt.tight_layout()
plt.subplots_adjust(left=0.08)

out = FIG_OUT / 'time_series_2yr.png'
plt.savefig(out, dpi=300, bbox_inches='tight')
plt.show()
print(f'Saved: {out}')
# Out:
# Saved: /cluster/home/siyan/github/WF-experiments/experiments/notebooks/figures/comparison_summary/time_series_2yr.png
